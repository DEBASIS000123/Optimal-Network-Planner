# %%
import pandas as pd
import numpy as np
import geopy.distance

# %%
data=pd.read_csv("D:/SupplementaryMaterial.csv")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9460\891056058.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("D:/SupplementaryMaterial.csv")

# %%
features=data[['Longitude','Latitude']]
features
# Out:
#       Longitude  Latitude
# 0      3.502389  6.437201
# 1      3.502389  6.437201
# 2      3.502389  6.437201
# 3      3.502389  6.437201
# 4      3.502389  6.437201
# ...         ...       ...
# 42493   3.41584  6.436213
# 42494   3.41584  6.436213
# 42495   3.41584  6.436213
# 42496   3.41584  6.436213
# 42497  3.415965  6.436205
#
# [42498 rows x 2 columns]

# %%
features.replace('\t',pd.NA,inplace=True)
features.replace(' ',pd.NA,inplace=True)
features=features.apply(pd.to_numeric,errors='coerce')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9460\2084207090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.replace('\t',pd.NA,inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_9460\2084207090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.replace(' ',pd.NA,inplace=True)

# %%
#Graphical Representation
coordList = []

for index, row in features.iterrows():
    if not (np.isnan(row['Latitude']) or np.isnan(row['Longitude'])):
        lat = row['Latitude']
        lon = row['Longitude']
        coordList.append([lat, lon])

import folium
from branca.element import Figure
import numpy as np
fig2 = Figure(width=1100, height=450)
m2 = folium.Map(location=[6.437201, 3.502389])

fig2.add_child(m2)



f1 = folium.FeatureGroup("Vehicle 1")
line_1 = folium.vector_layers.PolyLine(coordList, popup='<b>Path of Vehicle_1</b>', tooltip='Vehicle_1', color='purple', weight=2).add_to(f1)
f1.add_to(m2)

folium.LayerControl().add_to(m2)
m2.add_child(folium.Marker(location=[6.43720072, 3.50238888],popup='Start',icon=folium.Icon(color='green')))
m2.add_child(folium.Marker(location=[6.43620545, 3.41596484],popup='End',icon=folium.Icon(color='green')))
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Calculating total path
import numpy as np
features.replace('\t',pd.NA,inplace=True)
features.replace(' ',pd.NA,inplace=True)
features=features.apply(pd.to_numeric,errors='coerce')

coordList = []

for index, row in features.iterrows():
    if not (np.isnan(row['Latitude']) or np.isnan(row['Longitude'])):
        lat = row['Latitude']
        lon = row['Longitude']
        coordList.append((lat, lon))


total_distance = 0
for i in range(len(coordList) - 1):
    distance = geopy.distance.geodesic(coordList[i], coordList[i + 1]).kilometers
    total_distance += distance

print("Total path covered:", total_distance, "kilometers")
# Out:
# Total path covered: 274.7760067119096 kilometers
