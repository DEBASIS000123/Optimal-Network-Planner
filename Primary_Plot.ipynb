# %%
import pandas as pd
import numpy as np
import folium

# %%
data=pd.read_csv("D:/PathPlanning_Data.csv");
features=data[['Median Longitude','Median Latitude']]
features
# Out:
#      Median Longitude  Median Latitude
# 0            3.477728         6.449763
# 1            3.474728         6.445079
# 2            3.474807         6.445089
# 3            3.474786         6.445841
# 4            3.478069         6.447819
# ..                ...              ...
# 738          3.402229         6.455212
# 739          3.402215         6.455701
# 740          3.402218         6.456325
# 741          3.402180         6.456478
# 742          3.402216         6.456181
#
# [743 rows x 2 columns]

# %%
latitudes = data['Median Latitude']
longitudes = data['Median Longitude']

# Create a base map centered around the first entry (or any specific entry you prefer)
if not data.empty:
    center_lat = latitudes.iloc[0]
    center_lon = longitudes.iloc[0]
else:
    center_lat = 0
    center_lon = 0

map = folium.Map(location=[center_lat, center_lon], zoom_start=13)

# Add markers for each location
for lat, lon in zip(latitudes, longitudes):
    folium.Marker(location=[lat, lon]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cd7a4fbb2543491e6024d3f7fcf64bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cd7a4fbb2543491e6024d3f7fcf64bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cd7a4fbb2543491e6024d3f7fcf64bc = L.map(
#                 &quot;map_5cd7a4fbb2543491e6024d3f7fcf64bc&quot;,
#                 {
#                     center: [6.449763335, 3.47772821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_245ab838263c923eb32efe4b1b2b0b9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_245ab838263c923eb32efe4b1b2b0b9f.addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_bd8145ce040f94b146c669c9b31fe7ac = L.marker(
#                 [6.449763335, 3.47772821],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_74094dbff56a842fdb5db35c71a5b164 = L.marker(
#                 [6.44507905, 3.47472791],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_2e696f81a9f0fc4c085f7a9b3d0f3a93 = L.marker(
#                 [6.445088775, 3.474807195],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_f42afc7066baa0b427e94b71a59cebbb = L.marker(
#                 [6.44584092, 3.47478637],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_a511ee6776b0527c8da49ea2741ea0c1 = L.marker(
#                 [6.447819085, 3.478068675],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_02c59b04d0c7ee96d58580496279beae = L.marker(
#                 [6.44508956, 3.47480647],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_6638b83a90cca684075e1870dbd2b1e1 = L.marker(
#                 [6.44510152, 3.474753625],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_7b796ea20489cc3d7040b25aece62bc3 = L.marker(
#                 [6.44509965, 3.47480386],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_ef184bd02cff368c3e3e0f6bae9b2257 = L.marker(
#                 [6.43929944, 3.44637953],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_753282de81eb5e2da2d1cd5bff8b5e03 = L.marker(
#                 [6.4402696, 3.44438582],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_1d5fc8cb9bd6fd61b8b7dfcac4a43a65 = L.marker(
#                 [6.44019192, 3.44447599],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_04a873306f97acceef6992d507f04020 = L.marker(
#                 [6.44109085, 3.44526029],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_32d12c66d9fee3c908ae7daf9f8965a2 = L.marker(
#                 [6.44291374, 3.446240185],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_63d31945b683211bc48c812df81f9d69 = L.marker(
#                 [6.440255805, 3.445373255],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_ed25a855bcf8f0ad4fafbfbd1625cd2b = L.marker(
#                 [6.44214377, 3.44584736],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_72fddd7c7ac0af97f912995f061feb70 = L.marker(
#                 [6.44085687, 3.44487736],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_2f05d99768623759fc6514f48f94f52b = L.marker(
#                 [6.46111039, 3.3898976],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_19cc982d70988ddd0204d199fc6a43cd = L.marker(
#                 [6.46166551, 3.39085111],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_e1b3f662c8634f1b35f746f19d646e6d = L.marker(
#                 [6.46107719, 3.38909429],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_c6fe33bec36453de6af5309a618a07b5 = L.marker(
#                 [6.461547985, 3.39246134],
#                 {}
#             ).addTo(map_5cd7a4fbb2543491e6024d3f7fcf64bc);
#
#
#             var marker_28ac46e0360a3f295e6e5c90d77efd8a = L.marker(
#                 [6.46230289, 3.39
